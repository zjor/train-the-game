# %%
import torch
import numpy as np
from torch import nn
from torch.autograd import Variable

# %%
def load_data(filename):
    data = []
    with open(filename) as f:
        for line in f.readlines():
            line = list(map(float, line.strip().split(" ")))
            data.append([1.0] + line)
    data = np.matrix(data)
    X = data[:, 0:3]
    y = data[:, 3]
    return torch.tensor(X, dtype=torch.float), torch.tensor(y, dtype=torch.float)

X, y = load_data("data.txt")

# %%
dtype = torch.FloatTensor
w1 = Variable(torch.randn(3, 3).type(dtype), requires_grad=True)
w2 = Variable(torch.randn(3, 1).type(dtype), requires_grad=True)
# Out:
# tensor([[  1.0000, 206.0000, 200.0000],
#         [  1.0000, 206.0000, 200.0000],
#         [  1.0000, 203.0000, 200.0000],
#         ...,
#         [  1.0000, 175.0000, 197.2510],
#         [  1.0000, 172.0000, 196.7279],
#         [  1.0000, 172.0000, 196.2047]])

# %%
learning_rate = 1e-6
for t in range(500):
    y_pred = X.mm(w1).clamp(min=0).mm(w2)

    loss = (y_pred - y).pow(2).sum()
    print(t, loss)

    loss.backward()

    w1.data -= learning_rate * w1.grad.data
    w2.data -= learning_rate * w2.grad.data
    
    w1.grad.data.zero_()
    w2.grad.data.zero_()
# Out:
# 0 tensor(57536300., grad_fn=<SumBackward0>)
# 1 tensor(34234., grad_fn=<SumBackward0>)
# 2 tensor(34234., grad_fn=<SumBackward0>)
# 3 tensor(34234., grad_fn=<SumBackward0>)
# 4 tensor(34234., grad_fn=<SumBackward0>)
# 5 tensor(34234., grad_fn=<SumBackward0>)
# 6 tensor(34234., grad_fn=<SumBackward0>)
# 7 tensor(34234., grad_fn=<SumBackward0>)
# 8 tensor(34234., grad_fn=<SumBackward0>)
# 9 tensor(34234., grad_fn=<SumBackward0>)
# 10 tensor(34234., grad_fn=<SumBackward0>)
# 11 tensor(34234., grad_fn=<SumBackward0>)
# 12 tensor(34234., grad_fn=<SumBackward0>)
# 13 tensor(34234., grad_fn=<SumBackward0>)
# 14 tensor(34234., grad_fn=<SumBackward0>)
# 15 tensor(34234., grad_fn=<SumBackward0>)
# 16 tensor(34234., grad_fn=<SumBackward0>)
# 17 tensor(34234., grad_fn=<SumBackward0>)
# 18 tensor(34234., grad_fn=<SumBackward0>)
# 19 tensor(34234., grad_fn=<SumBackward0>)
# 20 tensor(34234., grad_fn=<SumBackward0>)
# 21 tensor(34234., grad_fn=<SumBackward0>)
# 22 tensor(34234., grad_fn=<SumBackward0>)
# 23 tensor(34234., grad_fn=<SumBackward0>)
# 24 tensor(34234., grad_fn=<SumBackward0>)
# 25 tensor(34234., grad_fn=<SumBackward0>)
# 26 tensor(34234., grad_fn=<SumBackward0>)
# 27 tensor(34234., grad_fn=<SumBackward0>)
# 28 tensor(34234., grad_fn=<SumBackward0>)
# 29 tensor(34234., grad_fn=<SumBackward0>)
# 30 tensor(34234., grad_fn=<SumBackward0>)
# 31 tensor(34234., grad_fn=<SumBackward0>)
# 32 tensor(34234., grad_fn=<SumBackward0>)
# 33 tensor(34234., grad_fn=<SumBackward0>)
# 34 tensor(34234., grad_fn=<SumBackward0>)
# 35 tensor(34234., grad_fn=<SumBackward0>)
# 36 tensor(34234., grad_fn=<SumBackward0>)
# 37 tensor(34234., grad_fn=<SumBackward0>)
# 38 tensor(34234., grad_fn=<SumBackward0>)
# 39 tensor(34234., grad_fn=<SumBackward0>)
# 40 tensor(34234., grad_fn=<SumBackward0>)
# 41 tensor(34234., grad_fn=<SumBackward0>)
# 42 tensor(34234., grad_fn=<SumBackward0>)
# 43 tensor(34234., grad_fn=<SumBackward0>)
# 44 tensor(34234., grad_fn=<SumBackward0>)
# 45 tensor(34234., grad_fn=<SumBackward0>)
# 46 tensor(34234., grad_fn=<SumBackward0>)
# 47 tensor(34234., grad_fn=<SumBackward0>)
# 48 tensor(34234., grad_fn=<SumBackward0>)
# 49 tensor(34234., grad_fn=<SumBackward0>)
# 50 tensor(34234., grad_fn=<SumBackward0>)
# 51 tensor(34234., grad_fn=<SumBackward0>)
# 52 tensor(34234., grad_fn=<SumBackward0>)
# 53 tensor(34234., grad_fn=<SumBackward0>)
# 54 tensor(34234., grad_fn=<SumBackward0>)
# 55 tensor(34234., grad_fn=<SumBackward0>)
# 56 tensor(34234., grad_fn=<SumBackward0>)
# 57 tensor(34234., grad_fn=<SumBackward0>)
# 58 tensor(34234., grad_fn=<SumBackward0>)
# 59 tensor(34234., grad_fn=<SumBackward0>)
# 60 tensor(34234., grad_fn=<SumBackward0>)
# 61 tensor(34234., grad_fn=<SumBackward0>)
# 62 tensor(34234., grad_fn=<SumBackward0>)
# 63 tensor(34234., grad_fn=<SumBackward0>)
# 64 tensor(34234., grad_fn=<SumBackward0>)
# 65 tensor(34234., grad_fn=<SumBackward0>)
# 66 tensor(34234., grad_fn=<SumBackward0>)
# 67 tensor(34234., grad_fn=<SumBackward0>)
# 68 tensor(34234., grad_fn=<SumBackward0>)
# 69 tensor(34234., grad_fn=<SumBackward0>)
# 70 tensor(34234., grad_fn=<SumBackward0>)
# 71 tensor(34234., grad_fn=<SumBackward0>)
# 72 tensor(34234., grad_fn=<SumBackward0>)
# 73 tensor(34234., grad_fn=<SumBackward0>)
# 74 tensor(34234., grad_fn=<SumBackward0>)
# 75 tensor(34234., grad_fn=<SumBackward0>)
# 76 tensor(34234., grad_fn=<SumBackward0>)
# 77 tensor(34234., grad_fn=<SumBackward0>)
# 78 tensor(34234., grad_fn=<SumBackward0>)
# 79 tensor(34234., grad_fn=<SumBackward0>)
# 80 tensor(34234., grad_fn=<SumBackward0>)
# 81 tensor(34234., grad_fn=<SumBackward0>)
# 82 tensor(34234., grad_fn=<SumBackward0>)
# 83 tensor(34234., grad_fn=<SumBackward0>)
# 84 tensor(34234., grad_fn=<SumBackward0>)
# 85 tensor(34234., grad_fn=<SumBackward0>)
# 86 tensor(34234., grad_fn=<SumBackward0>)
# 87 tensor(34234., grad_fn=<SumBackward0>)
# 88 tensor(34234., grad_fn=<SumBackward0>)
# 89 tensor(34234., grad_fn=<SumBackward0>)
# 90 tensor(34234., grad_fn=<SumBackward0>)
# 91 tensor(34234., grad_fn=<SumBackward0>)
# 92 tensor(34234., grad_fn=<SumBackward0>)
# 93 tensor(34234., grad_fn=<SumBackward0>)
# 94 tensor(34234., grad_fn=<SumBackward0>)
# 95 tensor(34234., grad_fn=<SumBackward0>)
# 96 tensor(34234., grad_fn=<SumBackward0>)
# 97 tensor(34234., grad_fn=<SumBackward0>)
# 98 tensor(34234., grad_fn=<SumBackward0>)
# 99 tensor(34234., grad_fn=<SumBackward0>)
# 100 tensor(34234., grad_fn=<SumBackward0>)
# 101 tensor(34234., grad_fn=<SumBackward0>)
# 102 tensor(34234., grad_fn=<SumBackward0>)
# 103 tensor(34234., grad_fn=<SumBackward0>)
# 104 tensor(34234., grad_fn=<SumBackward0>)
# 105 tensor(34234., grad_fn=<SumBackward0>)
# 106 tensor(34234., grad_fn=<SumBackward0>)
# 107 tensor(34234., grad_fn=<SumBackward0>)
# 108 tensor(34234., grad_fn=<SumBackward0>)
# 109 tensor(34234., grad_fn=<SumBackward0>)
# 110 tensor(34234., grad_fn=<SumBackward0>)
# 111 tensor(34234., grad_fn=<SumBackward0>)
# 112 tensor(34234., grad_fn=<SumBackward0>)
# 113 tensor(34234., grad_fn=<SumBackward0>)
# 114 tensor(34234., grad_fn=<SumBackward0>)
# 115 tensor(34234., grad_fn=<SumBackward0>)
# 116 tensor(34234., grad_fn=<SumBackward0>)
# 117 tensor(34234., grad_fn=<SumBackward0>)
# 118 tensor(34234., grad_fn=<SumBackward0>)
# 119 tensor(34234., grad_fn=<SumBackward0>)
# 120 tensor(34234., grad_fn=<SumBackward0>)
# 121 tensor(34234., grad_fn=<SumBackward0>)
# 122 tensor(34234., grad_fn=<SumBackward0>)
# 123 tensor(34234., grad_fn=<SumBackward0>)
# 124 tensor(34234., grad_fn=<SumBackward0>)
# 125 tensor(34234., grad_fn=<SumBackward0>)
# 126 tensor(34234., grad_fn=<SumBackward0>)
# 127 tensor(34234., grad_fn=<SumBackward0>)
# 128 tensor(34234., grad_fn=<SumBackward0>)
# 129 tensor(34234., grad_fn=<SumBackward0>)
# 130 tensor(34234., grad_fn=<SumBackward0>)
# 131 tensor(34234., grad_fn=<SumBackward0>)
# 132 tensor(34234., grad_fn=<SumBackward0>)
# 133 tensor(34234., grad_fn=<SumBackward0>)
# 134 tensor(34234., grad_fn=<SumBackward0>)
# 135 tensor(34234., grad_fn=<SumBackward0>)
# 136 tensor(34234., grad_fn=<SumBackward0>)
# 137 tensor(34234., grad_fn=<SumBackward0>)
# 138 tensor(34234., grad_fn=<SumBackward0>)
# 139 tensor(34234., grad_fn=<SumBackward0>)
# 140 tensor(34234., grad_fn=<SumBackward0>)
# 141 tensor(34234., grad_fn=<SumBackward0>)
# 142 tensor(34234., grad_fn=<SumBackward0>)
# 143 tensor(34234., grad_fn=<SumBackward0>)
# 144 tensor(34234., grad_fn=<SumBackward0>)
# 145 tensor(34234., grad_fn=<SumBackward0>)
# 146 tensor(34234., grad_fn=<SumBackward0>)
# 147 tensor(34234., grad_fn=<SumBackward0>)
# 148 tensor(34234., grad_fn=<SumBackward0>)
# 149 tensor(34234., grad_fn=<SumBackward0>)
# 150 tensor(34234., grad_fn=<SumBackward0>)
# 151 tensor(34234., grad_fn=<SumBackward0>)
# 152 tensor(34234., grad_fn=<SumBackward0>)
# 153 tensor(34234., grad_fn=<SumBackward0>)
# 154 tensor(34234., grad_fn=<SumBackward0>)
# 155 tensor(34234., grad_fn=<SumBackward0>)
# 156 tensor(34234., grad_fn=<SumBackward0>)
# 157 tensor(34234., grad_fn=<SumBackward0>)
# 158 tensor(34234., grad_fn=<SumBackward0>)
# 159 tensor(34234., grad_fn=<SumBackward0>)
# 160 tensor(34234., grad_fn=<SumBackward0>)
# 161 tensor(34234., grad_fn=<SumBackward0>)
# 162 tensor(34234., grad_fn=<SumBackward0>)
# 163 tensor(34234., grad_fn=<SumBackward0>)
# 164 tensor(34234., grad_fn=<SumBackward0>)
# 165 tensor(34234., grad_fn=<SumBackward0>)
# 166 tensor(34234., grad_fn=<SumBackward0>)
# 167 tensor(34234., grad_fn=<SumBackward0>)
# 168 tensor(34234., grad_fn=<SumBackward0>)
# 169 tensor(34234., grad_fn=<SumBackward0>)
# 170 tensor(34234., grad_fn=<SumBackward0>)
# 171 tensor(34234., grad_fn=<SumBackward0>)
# 172 tensor(34234., grad_fn=<SumBackward0>)
# 173 tensor(34234., grad_fn=<SumBackward0>)
# 174 tensor(34234., grad_fn=<SumBackward0>)
# 175 tensor(34234., grad_fn=<SumBackward0>)
# 176 tensor(34234., grad_fn=<SumBackward0>)
# 177 tensor(34234., grad_fn=<SumBackward0>)
# 178 tensor(34234., grad_fn=<SumBackward0>)
# 179 tensor(34234., grad_fn=<SumBackward0>)
# 180 tensor(34234., grad_fn=<SumBackward0>)
# 181 tensor(34234., grad_fn=<SumBackward0>)
# 182 tensor(34234., grad_fn=<SumBackward0>)
# 183 tensor(34234., grad_fn=<SumBackward0>)
# 184 tensor(34234., grad_fn=<SumBackward0>)
# 185 tensor(34234., grad_fn=<SumBackward0>)
# 186 tensor(34234., grad_fn=<SumBackward0>)
# 187 tensor(34234., grad_fn=<SumBackward0>)
# 188 tensor(34234., grad_fn=<SumBackward0>)
# 189 tensor(34234., grad_fn=<SumBackward0>)
# 190 tensor(34234., grad_fn=<SumBackward0>)
# 191 tensor(34234., grad_fn=<SumBackward0>)
# 192 tensor(34234., grad_fn=<SumBackward0>)
# 193 tensor(34234., grad_fn=<SumBackward0>)
# 194 tensor(34234., grad_fn=<SumBackward0>)
# 195 tensor(34234., grad_fn=<SumBackward0>)
# 196 tensor(34234., grad_fn=<SumBackward0>)
# 197 tensor(34234., grad_fn=<SumBackward0>)
# 198 tensor(34234., grad_fn=<SumBackward0>)
# 199 tensor(34234., grad_fn=<SumBackward0>)
# 200 tensor(34234., grad_fn=<SumBackward0>)
# 201 tensor(34234., grad_fn=<SumBackward0>)
# 202 tensor(34234., grad_fn=<SumBackward0>)
# 203 tensor(34234., grad_fn=<SumBackward0>)
# 204 tensor(34234., grad_fn=<SumBackward0>)
# 205 tensor(34234., grad_fn=<SumBackward0>)
# 206 tensor(34234., grad_fn=<SumBackward0>)
# 207 tensor(34234., grad_fn=<SumBackward0>)
# 208 tensor(34234., grad_fn=<SumBackward0>)
# 209 tensor(34234., grad_fn=<SumBackward0>)
# 210 tensor(34234., grad_fn=<SumBackward0>)
# 211 tensor(34234., grad_fn=<SumBackward0>)
# 212 tensor(34234., grad_fn=<SumBackward0>)
# 213 tensor(34234., grad_fn=<SumBackward0>)
# 214 tensor(34234., grad_fn=<SumBackward0>)
# 215 tensor(34234., grad_fn=<SumBackward0>)
# 216 tensor(34234., grad_fn=<SumBackward0>)
# 217 tensor(34234., grad_fn=<SumBackward0>)
# 218 tensor(34234., grad_fn=<SumBackward0>)
# 219 tensor(34234., grad_fn=<SumBackward0>)
# 220 tensor(34234., grad_fn=<SumBackward0>)
# 221 tensor(34234., grad_fn=<SumBackward0>)
# 222 tensor(34234., grad_fn=<SumBackward0>)
# 223 tensor(34234., grad_fn=<SumBackward0>)
# 224 tensor(34234., grad_fn=<SumBackward0>)
# 225 tensor(34234., grad_fn=<SumBackward0>)
# 226 tensor(34234., grad_fn=<SumBackward0>)
# 227 tensor(34234., grad_fn=<SumBackward0>)
# 228 tensor(34234., grad_fn=<SumBackward0>)
# 229 tensor(34234., grad_fn=<SumBackward0>)
# 230 tensor(34234., grad_fn=<SumBackward0>)
# 231 tensor(34234., grad_fn=<SumBackward0>)
# 232 tensor(34234., grad_fn=<SumBackward0>)
# 233 tensor(34234., grad_fn=<SumBackward0>)
# 234 tensor(34234., grad_fn=<SumBackward0>)
# 235 tensor(34234., grad_fn=<SumBackward0>)
# 236 tensor(34234., grad_fn=<SumBackward0>)
# 237 tensor(34234., grad_fn=<SumBackward0>)
# 238 tensor(34234., grad_fn=<SumBackward0>)
# 239 tensor(34234., grad_fn=<SumBackward0>)
# 240 tensor(34234., grad_fn=<SumBackward0>)
# 241 tensor(34234., grad_fn=<SumBackward0>)
# 242 tensor(34234., grad_fn=<SumBackward0>)
# 243 tensor(34234., grad_fn=<SumBackward0>)
# 244 tensor(34234., grad_fn=<SumBackward0>)
# 245 tensor(34234., grad_fn=<SumBackward0>)
# 246 tensor(34234., grad_fn=<SumBackward0>)
# 247 tensor(34234., grad_fn=<SumBackward0>)
# 248 tensor(34234., grad_fn=<SumBackward0>)
# 249 tensor(34234., grad_fn=<SumBackward0>)
# 250 tensor(34234., grad_fn=<SumBackward0>)
# 251 tensor(34234., grad_fn=<SumBackward0>)
# 252 tensor(34234., grad_fn=<SumBackward0>)
# 253 tensor(34234., grad_fn=<SumBackward0>)
# 254 tensor(34234., grad_fn=<SumBackward0>)
# 255 tensor(34234., grad_fn=<SumBackward0>)
# 256 tensor(34234., grad_fn=<SumBackward0>)
# 257 tensor(34234., grad_fn=<SumBackward0>)
# 258 tensor(34234., grad_fn=<SumBackward0>)
# 259 tensor(34234., grad_fn=<SumBackward0>)
# 260 tensor(34234., grad_fn=<SumBackward0>)
# 261 tensor(34234., grad_fn=<SumBackward0>)
# 262 tensor(34234., grad_fn=<SumBackward0>)
# 263 tensor(34234., grad_fn=<SumBackward0>)
# 264 tensor(34234., grad_fn=<SumBackward0>)
# 265 tensor(34234., grad_fn=<SumBackward0>)
# 266 tensor(34234., grad_fn=<SumBackward0>)
# 267 tensor(34234., grad_fn=<SumBackward0>)
# 268 tensor(34234., grad_fn=<SumBackward0>)
# 269 tensor(34234., grad_fn=<SumBackward0>)
# 270 tensor(34234., grad_fn=<SumBackward0>)
# 271 tensor(34234., grad_fn=<SumBackward0>)
# 272 tensor(34234., grad_fn=<SumBackward0>)
# 273 tensor(34234., grad_fn=<SumBackward0>)
# 274 tensor(34234., grad_fn=<SumBackward0>)
# 275 tensor(34234., grad_fn=<SumBackward0>)
# 276 tensor(34234., grad_fn=<SumBackward0>)
# 277 tensor(34234., grad_fn=<SumBackward0>)
# 278 tensor(34234., grad_fn=<SumBackward0>)
# 279 tensor(34234., grad_fn=<SumBackward0>)
# 280 tensor(34234., grad_fn=<SumBackward0>)
# 281 tensor(34234., grad_fn=<SumBackward0>)
# 282 tensor(34234., grad_fn=<SumBackward0>)
# 283 tensor(34234., grad_fn=<SumBackward0>)
# 284 tensor(34234., grad_fn=<SumBackward0>)
# 285 tensor(34234., grad_fn=<SumBackward0>)
# 286 tensor(34234., grad_fn=<SumBackward0>)
# 287 tensor(34234., grad_fn=<SumBackward0>)
# 288 tensor(34234., grad_fn=<SumBackward0>)
# 289 tensor(34234., grad_fn=<SumBackward0>)
# 290 tensor(34234., grad_fn=<SumBackward0>)
# 291 tensor(34234., grad_fn=<SumBackward0>)
# 292 tensor(34234., grad_fn=<SumBackward0>)
# 293 tensor(34234., grad_fn=<SumBackward0>)
# 294 tensor(34234., grad_fn=<SumBackward0>)
# 295 tensor(34234., grad_fn=<SumBackward0>)
# 296 tensor(34234., grad_fn=<SumBackward0>)
# 297 tensor(34234., grad_fn=<SumBackward0>)
# 298 tensor(34234., grad_fn=<SumBackward0>)
# 299 tensor(34234., grad_fn=<SumBackward0>)
# 300 tensor(34234., grad_fn=<SumBackward0>)
# 301 tensor(34234., grad_fn=<SumBackward0>)
# 302 tensor(34234., grad_fn=<SumBackward0>)
# 303 tensor(34234., grad_fn=<SumBackward0>)
# 304 tensor(34234., grad_fn=<SumBackward0>)
# 305 tensor(34234., grad_fn=<SumBackward0>)
# 306 tensor(34234., grad_fn=<SumBackward0>)
# 307 tensor(34234., grad_fn=<SumBackward0>)
# 308 tensor(34234., grad_fn=<SumBackward0>)
# 309 tensor(34234., grad_fn=<SumBackward0>)
# 310 tensor(34234., grad_fn=<SumBackward0>)
# 311 tensor(34234., grad_fn=<SumBackward0>)
# 312 tensor(34234., grad_fn=<SumBackward0>)
# 313 tensor(34234., grad_fn=<SumBackward0>)
# 314 tensor(34234., grad_fn=<SumBackward0>)
# 315 tensor(34234., grad_fn=<SumBackward0>)
# 316 tensor(34234., grad_fn=<SumBackward0>)
# 317 tensor(34234., grad_fn=<SumBackward0>)
# 318 tensor(34234., grad_fn=<SumBackward0>)
# 319 tensor(34234., grad_fn=<SumBackward0>)
# 320 tensor(34234., grad_fn=<SumBackward0>)
# 321 tensor(34234., grad_fn=<SumBackward0>)
# 322 tensor(34234., grad_fn=<SumBackward0>)
# 323 tensor(34234., grad_fn=<SumBackward0>)
# 324 tensor(34234., grad_fn=<SumBackward0>)
# 325 tensor(34234., grad_fn=<SumBackward0>)
# 326 tensor(34234., grad_fn=<SumBackward0>)
# 327 tensor(34234., grad_fn=<SumBackward0>)
# 328 tensor(34234., grad_fn=<SumBackward0>)
# 329 tensor(34234., grad_fn=<SumBackward0>)
# 330 tensor(34234., grad_fn=<SumBackward0>)
# 331 tensor(34234., grad_fn=<SumBackward0>)
# 332 tensor(34234., grad_fn=<SumBackward0>)
# 333 tensor(34234., grad_fn=<SumBackward0>)
# 334 tensor(34234., grad_fn=<SumBackward0>)
# 335 tensor(34234., grad_fn=<SumBackward0>)
# 336 tensor(34234., grad_fn=<SumBackward0>)
# 337 tensor(34234., grad_fn=<SumBackward0>)
# 338 tensor(34234., grad_fn=<SumBackward0>)
# 339 tensor(34234., grad_fn=<SumBackward0>)
# 340 tensor(34234., grad_fn=<SumBackward0>)
# 341 tensor(34234., grad_fn=<SumBackward0>)
# 342 tensor(34234., grad_fn=<SumBackward0>)
# 343 tensor(34234., grad_fn=<SumBackward0>)
# 344 tensor(34234., grad_fn=<SumBackward0>)
# 345 tensor(34234., grad_fn=<SumBackward0>)
# 346 tensor(34234., grad_fn=<SumBackward0>)
# 347 tensor(34234., grad_fn=<SumBackward0>)
# 348 tensor(34234., grad_fn=<SumBackward0>)
# 349 tensor(34234., grad_fn=<SumBackward0>)
# 350 tensor(34234., grad_fn=<SumBackward0>)
# 351 tensor(34234., grad_fn=<SumBackward0>)
# 352 tensor(34234., grad_fn=<SumBackward0>)
# 353 tensor(34234., grad_fn=<SumBackward0>)
# 354 tensor(34234., grad_fn=<SumBackward0>)
# 355 tensor(34234., grad_fn=<SumBackward0>)
# 356 tensor(34234., grad_fn=<SumBackward0>)
# 357 tensor(34234., grad_fn=<SumBackward0>)
# 358 tensor(34234., grad_fn=<SumBackward0>)
# 359 tensor(34234., grad_fn=<SumBackward0>)
# 360 tensor(34234., grad_fn=<SumBackward0>)
# 361 tensor(34234., grad_fn=<SumBackward0>)
# 362 tensor(34234., grad_fn=<SumBackward0>)
# 363 tensor(34234., grad_fn=<SumBackward0>)
# 364 tensor(34234., grad_fn=<SumBackward0>)
# 365 tensor(34234., grad_fn=<SumBackward0>)
# 366 tensor(34234., grad_fn=<SumBackward0>)
# 367 tensor(34234., grad_fn=<SumBackward0>)
# 368 tensor(34234., grad_fn=<SumBackward0>)
# 369 tensor(34234., grad_fn=<SumBackward0>)
# 370 tensor(34234., grad_fn=<SumBackward0>)
# 371 tensor(34234., grad_fn=<SumBackward0>)
# 372 tensor(34234., grad_fn=<SumBackward0>)
# 373 tensor(34234., grad_fn=<SumBackward0>)
# 374 tensor(34234., grad_fn=<SumBackward0>)
# 375 tensor(34234., grad_fn=<SumBackward0>)
# 376 tensor(34234., grad_fn=<SumBackward0>)
# 377 tensor(34234., grad_fn=<SumBackward0>)
# 378 tensor(34234., grad_fn=<SumBackward0>)
# 379 tensor(34234., grad_fn=<SumBackward0>)
# 380 tensor(34234., grad_fn=<SumBackward0>)
# 381 tensor(34234., grad_fn=<SumBackward0>)
# 382 tensor(34234., grad_fn=<SumBackward0>)
# 383 tensor(34234., grad_fn=<SumBackward0>)
# 384 tensor(34234., grad_fn=<SumBackward0>)
# 385 tensor(34234., grad_fn=<SumBackward0>)
# 386 tensor(34234., grad_fn=<SumBackward0>)
# 387 tensor(34234., grad_fn=<SumBackward0>)
# 388 tensor(34234., grad_fn=<SumBackward0>)
# 389 tensor(34234., grad_fn=<SumBackward0>)
# 390 tensor(34234., grad_fn=<SumBackward0>)
# 391 tensor(34234., grad_fn=<SumBackward0>)
# 392 tensor(34234., grad_fn=<SumBackward0>)
# 393 tensor(34234., grad_fn=<SumBackward0>)
# 394 tensor(34234., grad_fn=<SumBackward0>)
# 395 tensor(34234., grad_fn=<SumBackward0>)
# 396 tensor(34234., grad_fn=<SumBackward0>)
# 397 tensor(34234., grad_fn=<SumBackward0>)
# 398 tensor(34234., grad_fn=<SumBackward0>)
# 399 tensor(34234., grad_fn=<SumBackward0>)
# 400 tensor(34234., grad_fn=<SumBackward0>)
# 401 tensor(34234., grad_fn=<SumBackward0>)
# 402 tensor(34234., grad_fn=<SumBackward0>)
# 403 tensor(34234., grad_fn=<SumBackward0>)
# 404 tensor(34234., grad_fn=<SumBackward0>)
# 405 tensor(34234., grad_fn=<SumBackward0>)
# 406 tensor(34234., grad_fn=<SumBackward0>)
# 407 tensor(34234., grad_fn=<SumBackward0>)
# 408 tensor(34234., grad_fn=<SumBackward0>)
# 409 tensor(34234., grad_fn=<SumBackward0>)
# 410 tensor(34234., grad_fn=<SumBackward0>)
# 411 tensor(34234., grad_fn=<SumBackward0>)
# 412 tensor(34234., grad_fn=<SumBackward0>)
# 413 tensor(34234., grad_fn=<SumBackward0>)
# 414 tensor(34234., grad_fn=<SumBackward0>)
# 415 tensor(34234., grad_fn=<SumBackward0>)
# 416 tensor(34234., grad_fn=<SumBackward0>)
# 417 tensor(34234., grad_fn=<SumBackward0>)
# 418 tensor(34234., grad_fn=<SumBackward0>)
# 419 tensor(34234., grad_fn=<SumBackward0>)
# 420 tensor(34234., grad_fn=<SumBackward0>)
# 421 tensor(34234., grad_fn=<SumBackward0>)
# 422 tensor(34234., grad_fn=<SumBackward0>)
# 423 tensor(34234., grad_fn=<SumBackward0>)
# 424 tensor(34234., grad_fn=<SumBackward0>)
# 425 tensor(34234., grad_fn=<SumBackward0>)
# 426 tensor(34234., grad_fn=<SumBackward0>)
# 427 tensor(34234., grad_fn=<SumBackward0>)
# 428 tensor(34234., grad_fn=<SumBackward0>)
# 429 tensor(34234., grad_fn=<SumBackward0>)
# 430 tensor(34234., grad_fn=<SumBackward0>)
# 431 tensor(34234., grad_fn=<SumBackward0>)
# 432 tensor(34234., grad_fn=<SumBackward0>)
# 433 tensor(34234., grad_fn=<SumBackward0>)
# 434 tensor(34234., grad_fn=<SumBackward0>)
# 435 tensor(34234., grad_fn=<SumBackward0>)
# 436 tensor(34234., grad_fn=<SumBackward0>)
# 437 tensor(34234., grad_fn=<SumBackward0>)
# 438 tensor(34234., grad_fn=<SumBackward0>)
# 439 tensor(34234., grad_fn=<SumBackward0>)
# 440 tensor(34234., grad_fn=<SumBackward0>)
# 441 tensor(34234., grad_fn=<SumBackward0>)
# 442 tensor(34234., grad_fn=<SumBackward0>)
# 443 tensor(34234., grad_fn=<SumBackward0>)
# 444 tensor(34234., grad_fn=<SumBackward0>)
# 445 tensor(34234., grad_fn=<SumBackward0>)
# 446 tensor(34234., grad_fn=<SumBackward0>)
# 447 tensor(34234., grad_fn=<SumBackward0>)
# 448 tensor(34234., grad_fn=<SumBackward0>)
# 449 tensor(34234., grad_fn=<SumBackward0>)
# 450 tensor(34234., grad_fn=<SumBackward0>)
# 451 tensor(34234., grad_fn=<SumBackward0>)
# 452 tensor(34234., grad_fn=<SumBackward0>)
# 453 tensor(34234., grad_fn=<SumBackward0>)
# 454 tensor(34234., grad_fn=<SumBackward0>)
# 455 tensor(34234., grad_fn=<SumBackward0>)
# 456 tensor(34234., grad_fn=<SumBackward0>)
# 457 tensor(34234., grad_fn=<SumBackward0>)
# 458 tensor(34234., grad_fn=<SumBackward0>)
# 459 tensor(34234., grad_fn=<SumBackward0>)
# 460 tensor(34234., grad_fn=<SumBackward0>)
# 461 tensor(34234., grad_fn=<SumBackward0>)
# 462 tensor(34234., grad_fn=<SumBackward0>)
# 463 tensor(34234., grad_fn=<SumBackward0>)
# 464 tensor(34234., grad_fn=<SumBackward0>)
# 465 tensor(34234., grad_fn=<SumBackward0>)
# 466 tensor(34234., grad_fn=<SumBackward0>)
# 467 tensor(34234., grad_fn=<SumBackward0>)
# 468 tensor(34234., grad_fn=<SumBackward0>)
# 469 tensor(34234., grad_fn=<SumBackward0>)
# 470 tensor(34234., grad_fn=<SumBackward0>)
# 471 tensor(34234., grad_fn=<SumBackward0>)
# 472 tensor(34234., grad_fn=<SumBackward0>)
# 473 tensor(34234., grad_fn=<SumBackward0>)
# 474 tensor(34234., grad_fn=<SumBackward0>)
# 475 tensor(34234., grad_fn=<SumBackward0>)
# 476 tensor(34234., grad_fn=<SumBackward0>)
# 477 tensor(34234., grad_fn=<SumBackward0>)
# 478 tensor(34234., grad_fn=<SumBackward0>)
# 479 tensor(34234., grad_fn=<SumBackward0>)
# 480 tensor(34234., grad_fn=<SumBackward0>)
# 481 tensor(34234., grad_fn=<SumBackward0>)
# 482 tensor(34234., grad_fn=<SumBackward0>)
# 483 tensor(34234., grad_fn=<SumBackward0>)
# 484 tensor(34234., grad_fn=<SumBackward0>)
# 485 tensor(34234., grad_fn=<SumBackward0>)
# 486 tensor(34234., grad_fn=<SumBackward0>)
# 487 tensor(34234., grad_fn=<SumBackward0>)
# 488 tensor(34234., grad_fn=<SumBackward0>)
# 489 tensor(34234., grad_fn=<SumBackward0>)
# 490 tensor(34234., grad_fn=<SumBackward0>)
# 491 tensor(34234., grad_fn=<SumBackward0>)
# 492 tensor(34234., grad_fn=<SumBackward0>)
# 493 tensor(34234., grad_fn=<SumBackward0>)
# 494 tensor(34234., grad_fn=<SumBackward0>)
# 495 tensor(34234., grad_fn=<SumBackward0>)
# 496 tensor(34234., grad_fn=<SumBackward0>)
# 497 tensor(34234., grad_fn=<SumBackward0>)
# 498 tensor(34234., grad_fn=<SumBackward0>)
# 499 tensor(34234., grad_fn=<SumBackward0>)
